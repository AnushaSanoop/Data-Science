# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushaSanoop/Data-Science/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load dataset
from sklearn.datasets import load_iris
data=load_iris()
data

# %%
#sort as train and test dataset
x,y=data.data,data.target
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
 #using classifier create model
 from sklearn.linear_model import LinearRegression
 linreg=LinearRegression()
 linreg.fit(x_train,y_train)
 linreg.intercept_
# Out:
# 0.2504366864716264

# %%
linreg.coef_
# Out:
# array([-0.12708331, -0.03643167,  0.23595444,  0.59665846])

# %%
#calculate regression score
linreg.score(x_test,y_pred)
# Out:
# 1.0

# %%
y_pred = linreg.predict(x_test)
y_pred
# Out:
# array([ 1.81146356,  1.90942248,  1.18715942,  1.05821031,  0.05131954,
#         1.20706931,  1.70449842,  1.82770738,  1.41167449,  1.12376563,
#         0.00804758,  0.18153908, -0.05553646, -0.03189863,  0.90653542,
#         1.68683483, -0.02675239,  1.96908833,  1.75200672,  1.99628455,
#         2.11534048,  1.26150414,  1.17987308,  1.17987455,  0.03291419,
#        -0.01586528,  1.80807179,  1.48254707,  1.15956174, -0.06646596])

# %%
#plot using matplotlib
import matplotlib.pyplot as plt
plt.plot(x_train,y_train)
